# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def open_csv(file_path):
    """
    Opens and reads a CSV file using pandas.

    Parameters:
    file_path (str): The path to the CSV file.

    Returns:
    DataFrame: A pandas DataFrame containing the CSV data.
    """
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print(f"The file at {file_path} was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %%
#File paths for each CSV
apple_store_path = (r"../data/Apple store/AppleStore_cleaned.csv")
googleplay_store_path = (r"../data/Google Playstore/googleplaystore_cleaned.csv")

# %%
#DF for each CSV
apple_df = open_csv(apple_store_path)
google_df = open_csv(googleplay_store_path)

# %%
def freq_table(df, column):
    """
    Generates and displays a frequency table for a given column in a DataFrame,
    showing the percentage of each unique value, sorted in descending order.

    Parameters:
    df (pd.DataFrame): The DataFrame containing the data.
    column (str): The name of the column to generate and display the frequency table for.

    Returns:
    pd.DataFrame: A DataFrame with unique values and their corresponding percentages, sorted in descending order.
    """
    # Calculate value counts and convert to percentages
    value_counts = df[column].value_counts(normalize=True) * 100
    
    # Create the frequency table DataFrame
    freq_df = value_counts.reset_index().rename(columns={'index': column, column: 'Percentage'})
    
    # Sort the DataFrame by the 'Percentage' column in descending order
    freq_df_sorted = freq_df.sort_values(by='Percentage', ascending=False)
    
    # Display the sorted frequency table
    print(freq_df_sorted.to_string(index=False))
    
    # Return the sorted frequency table as a DataFrame
    return freq_df_sorted

# %%
apple_frequency_table = freq_table(apple_df, 'prime_genre')
print(apple_frequency_table)
# Out:
#       prime_genre  Percentage
#             Games   59.171800
#     Entertainment    7.529090
#     Photo & Video    5.133470
#         Education    3.832991
# Social Networking    3.114305
#          Shopping    2.498289
#         Utilities    2.258727
#             Music    2.156057
#            Sports    2.053388
#  Health & Fitness    1.984942
#      Productivity    1.711157
#         Lifestyle    1.471595
#              News    1.334702
#            Travel    1.129363
#           Finance    1.095140
#           Weather    0.889802
#      Food & Drink    0.889802
#          Business    0.513347
#         Reference    0.513347
#              Book    0.273785
#           Medical    0.205339
#        Navigation    0.136893
#          Catalogs    0.102669
#           prime_genre  Percentage
# 0               Games   59.171800
# 1       Entertainment    7.529090
# 2       Photo & Video    5.133470
# 3           Education    3.832991
# 4   Social Networking    3.114305
# 5            Shopping    2.498289
# 6           Utilities    2.258727
# 7               Music    2.156057
# 8              Sports    2.053388
# 9    Health & Fitness    1.984942
# 10       Productivity    1.711157
# 11          Lifestyle    1.471595
# 12               News    1.334702
# 13             Travel    1.129363
# 14            Finance    1.095140
# 15            Weather    0.889802
# 16       Food & Drink    0.889802
# 17           Business    0.513347
# 18          Reference    0.513347
# 19               Book    0.273785
# 20            Medical    0.205339
# 21         Navigation    0.136893
# 22           Catalogs    0.102669

# %%
google_frequency_table = freq_table(google_df, 'Category')
print(google_frequency_table)
# Out:
#            Category  Percentage
#              FAMILY   18.793862
#                GAME    9.611038
#               TOOLS    8.576187
#            BUSINESS    4.710360
#        PRODUCTIVITY    3.972880
#           LIFESTYLE    3.889616
#             FINANCE    3.734983
#             MEDICAL    3.639824
#     PERSONALIZATION    3.306768
#              SPORTS    3.259189
#       COMMUNICATION    3.223504
#  HEALTH_AND_FITNESS    3.128345
#         PHOTOGRAPHY    3.009397
#  NEWS_AND_MAGAZINES    2.795290
#              SOCIAL    2.664446
#    TRAVEL_AND_LOCAL    2.307601
#            SHOPPING    2.248127
# BOOKS_AND_REFERENCE    2.188652
#              DATING    1.831807
#       VIDEO_PLAYERS    1.760438
# MAPS_AND_NAVIGATION    1.356013
#      FOOD_AND_DRINK    1.201380
#           EDUCATION    1.165695
#   AUTO_AND_VEHICLES    0.939693
#       ENTERTAINMENT    0.939693
#  LIBRARIES_AND_DEMO    0.904009
#      HOUSE_AND_HOME    0.808850
#             WEATHER    0.796955
#              EVENTS    0.713691
#      ART_AND_DESIGN    0.666112
#           PARENTING    0.654217
#              BEAUTY    0.630427
#              COMICS    0.570953
#                Category  Percentage
# 0                FAMILY   18.793862
# 1                  GAME    9.611038
# 2                 TOOLS    8.576187
# 3              BUSINESS    4.710360
# 4          PRODUCTIVITY    3.972880
# 5             LIFESTYLE    3.889616
# 6               FINANCE    3.734983
# 7               MEDICAL    3.639824
# 8       PERSONALIZATION    3.306768
# 9                SPORTS    3.259189
# 10        COMMUNICATION    3.223504
# 11   HEALTH_AND_FITNESS    3.128345
# 12          PHOTOGRAPHY    3.009397
# 13   NEWS_AND_MAGAZINES    2.795290
# 14               SOCIAL    2.664446
# 15     TRAVEL_AND_LOCAL    2.307601
# 16             SHOPPING    2.248127
# 17  BOOKS_AND_REFERENCE    2.188652
# 18               DATING    1.831807
# 19        VIDEO_PLAYERS    1.760438
# 20  MAPS_AND_NAVIGATION    1.356013
# 21       FOOD_AND_DRINK    1.201380
# 22            EDUCATION    1.165695
# 23    AUTO_AND_VEHICLES    0.939693
# 24        ENTERTAINMENT    0.939693
# 25   LIBRARIES_AND_DEMO    0.904009
# 26       HOUSE_AND_HOME    0.808850
# 27              WEATHER    0.796955
# 28               EVENTS    0.713691
# 29       ART_AND_DESIGN    0.666112
# 30            PARENTING    0.654217
# 31               BEAUTY    0.630427
# 32               COMICS    0.570953

# %%
google_frequency_table = freq_table(google_df, 'Genres')
print(google_frequency_table)
# Out:
#                                Genres  Percentage
#                                 Tools    8.564292
#                         Entertainment    6.090163
#                             Education    5.388367
#                              Business    4.710360
#                          Productivity    3.972880
#                             Lifestyle    3.877721
#                               Finance    3.734983
#                               Medical    3.639824
#                                Sports    3.330558
#                       Personalization    3.306768
#                         Communication    3.223504
#                      Health & Fitness    3.128345
#                                Action    3.116451
#                           Photography    3.009397
#                      News & Magazines    2.795290
#                                Social    2.664446
#                        Travel & Local    2.307601
#                              Shopping    2.248127
#                     Books & Reference    2.188652
#                            Simulation    2.081599
#                                Arcade    1.831807
#                                Dating    1.831807
#                                Casual    1.772333
#               Video Players & Editors    1.736648
#                     Maps & Navigation    1.356013
#                          Food & Drink    1.201380
#                                Puzzle    1.130011
#                                Racing    1.022957
#                       Auto & Vehicles    0.939693
#                          Role Playing    0.939693
#                      Libraries & Demo    0.904009
#                              Strategy    0.892114
#                          House & Home    0.808850
#                               Weather    0.796955
#                                Events    0.713691
#                             Adventure    0.654217
#                                Beauty    0.630427
#                          Art & Design    0.618532
#                                Comics    0.559058
#                             Parenting    0.499584
#                 Educational;Education    0.416320
#                                Trivia    0.416320
#                                  Card    0.404425
#                                Casino    0.380635
#                           Educational    0.380635
#                                 Board    0.368740
#                   Education;Education    0.344951
#                                  Word    0.249792
#                                 Music    0.202212
#                   Casual;Pretend Play    0.190318
#                    Puzzle;Brain Games    0.178423
#                    Casual;Brain Games    0.142738
#             Racing;Action & Adventure    0.142738
#             Casual;Action & Adventure    0.130843
#           Entertainment;Music & Video    0.130843
#             Arcade;Action & Adventure    0.107054
#         Simulation;Action & Adventure    0.083264
#                   Parenting;Education    0.083264
#              Educational;Pretend Play    0.083264
#             Action;Action & Adventure    0.083264
#             Entertainment;Brain Games    0.071369
#               Art & Design;Creativity    0.071369
#               Parenting;Music & Video    0.059474
#                Education;Pretend Play    0.059474
#                     Board;Brain Games    0.059474
#               Educational;Brain Games    0.047579
#             Role Playing;Pretend Play    0.047579
#                  Education;Creativity    0.047579
#                     Casual;Creativity    0.047579
#                Educational;Creativity    0.035685
#          Education;Action & Adventure    0.035685
#             Puzzle;Action & Adventure    0.035685
#       Role Playing;Action & Adventure    0.035685
#          Adventure;Action & Adventure    0.035685
#               Education;Music & Video    0.035685
#                     Puzzle;Creativity    0.023790
#              Board;Action & Adventure    0.023790
#        Educational;Action & Adventure    0.023790
#               Simulation;Pretend Play    0.023790
#             Sports;Action & Adventure    0.023790
#                      Casual;Education    0.023790
# Video Players & Editors;Music & Video    0.023790
#                   Music;Music & Video    0.023790
#                 Education;Brain Games    0.023790
#              Entertainment;Creativity    0.023790
#      Entertainment;Action & Adventure    0.023790
#            Entertainment;Pretend Play    0.023790
#                    Strategy;Education    0.011895
#                      Trivia;Education    0.011895
#               Card;Action & Adventure    0.011895
#             Art & Design;Pretend Play    0.011895
#           Books & Reference;Education    0.011895
#   Health & Fitness;Action & Adventure    0.011895
#               Entertainment;Education    0.011895
#              Role Playing;Brain Games    0.011895
#                   Adventure;Education    0.011895
#                   Racing;Pretend Play    0.011895
#                 Parenting;Brain Games    0.011895
#       Art & Design;Action & Adventure    0.011895
#                   Strategy;Creativity    0.011895
#                     Comics;Creativity    0.011895
#                  Simulation;Education    0.011895
#           Music & Audio;Music & Video    0.011895
#            Health & Fitness;Education    0.011895
#                Lifestyle;Pretend Play    0.011895
#                       Tools;Education    0.011895
#                      Puzzle;Education    0.011895
#    Video Players & Editors;Creativity    0.011895
#                                  Genres  Percentage
# 0                                 Tools    8.564292
# 1                         Entertainment    6.090163
# 2                             Education    5.388367
# 3                              Business    4.710360
# 4                          Productivity    3.972880
# ..                                  ...         ...
# 90           Health & Fitness;Education    0.011895
# 89               Lifestyle;Pretend Play    0.011895
# 88                      Tools;Education    0.011895
# 87                     Puzzle;Education    0.011895
# 107  Video Players & Editors;Creativity    0.011895
#
# [108 rows x 2 columns]

# %%
def average_installs_by_category(android_df):
    """
    Calculates the average number of installs for each category in the Android dataset.

    Parameters:
    android_df (pd.DataFrame): The DataFrame containing Android app data.

    Returns:
    pd.DataFrame: A DataFrame containing categories and their corresponding average installs, sorted by highest.
    """
    # Clean the 'Installs' column to remove commas and plus signs, then convert to float
    android_df['Installs'] = android_df['Installs'].str.replace(',', '').str.replace('+', '').astype(float)
    
    # Group by 'Category' and calculate the mean of installs
    avg_installs = android_df.groupby('Category')['Installs'].mean().reset_index()
    avg_installs = avg_installs.rename(columns={'Installs': 'Average Installs'})
    
    # Sort the DataFrame by 'Average Installs' in descending order
    avg_installs = avg_installs.sort_values(by='Average Installs', ascending=False)
    
    # Print the results
    for index, row in avg_installs.iterrows():
        print(row['Category'], ':', row['Average Installs'])
    
    return avg_installs

# %%
google_genre_avg = average_installs_by_category(google_df)
# Out:
# COMMUNICATION : 36106662.328413285
# VIDEO_PLAYERS : 25234606.216216218
# SOCIAL : 24441088.17857143
# PHOTOGRAPHY : 18099283.85375494
# PRODUCTIVITY : 16972497.946107786
# GAME : 15434835.816831684
# TRAVEL_AND_LOCAL : 14487541.68041237
# ENTERTAINMENT : 12346329.11392405
# TOOLS : 11084333.292649098
# NEWS_AND_MAGAZINES : 10006311.10638298
# BOOKS_AND_REFERENCE : 8504745.97826087
# SHOPPING : 7307823.2010582015
# WEATHER : 5219216.7164179105
# PERSONALIZATION : 5027006.791366907
# MAPS_AND_NAVIGATION : 4304432.280701755
# HEALTH_AND_FITNESS : 4263642.1749049425
# SPORTS : 3647640.208029197
# FAMILY : 3636007.157594937
# FOOD_AND_DRINK : 1974937.1386138613
# ART_AND_DESIGN : 1932519.642857143
# EDUCATION : 1844897.9591836734
# BUSINESS : 1602958.308080808
# HOUSE_AND_HOME : 1391211.1911764706
# LIFESTYLE : 1375297.3058103975
# FINANCE : 1348224.9426751593
# COMICS : 880440.625
# DATING : 764959.4610389611
# LIBRARIES_AND_DEMO : 674917.2368421053
# AUTO_AND_VEHICLES : 645317.2278481013
# PARENTING : 544745.6363636364
# BEAUTY : 513151.88679245283
# EVENTS : 232885.83333333334
# MEDICAL : 119216.81045751635
# C:\Users\ByakkoMao\AppData\Local\Temp\ipykernel_13988\2753143092.py:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   android_df['Installs'] = android_df['Installs'].str.replace(',', '').str.replace('+', '').astype(float)

# %%
def average_ratings_by_genre(ios_df):
    """
    Calculates the average number of ratings for each genre in the iOS dataset.

    Parameters:
    ios_df (pd.DataFrame): The DataFrame containing iOS app data.

    Returns:
    pd.DataFrame: A DataFrame containing genres and their corresponding average ratings, sorted by highest.
    """
    # Group by genre and calculate the mean of ratings
    avg_ratings = ios_df.groupby('prime_genre')['rating_count_tot'].mean().reset_index()
    avg_ratings = avg_ratings.rename(columns={'rating_count_tot': 'Average Ratings'})
    
    # Sort the DataFrame by 'Average Ratings' in descending order
    avg_ratings = avg_ratings.sort_values(by='Average Ratings', ascending=False)
    
    # Print the results
    for index, row in avg_ratings.iterrows():
        print(row['prime_genre'], ':', row['Average Ratings'])
    
    return avg_ratings

# %%
apple_genre_avg = average_ratings_by_genre(apple_df)
# Out:
# Navigation : 125037.25
# Reference : 89562.6
# Social Networking : 78567.30769230769
# Music : 55396.01587301587
# Weather : 48275.57692307692
# Travel : 34115.57575757576
# Food & Drink : 33333.92307692308
# Photo & Video : 29249.766666666666
# Shopping : 28877.575342465752
# Finance : 26038.6875
# Sports : 25791.666666666668
# News : 23382.17948717949
# Productivity : 22842.22
# Games : 21560.75072296125
# Health & Fitness : 19418.620689655174
# Lifestyle : 17260.53488372093
# Book : 16671.0
# Entertainment : 15006.227272727272
# Utilities : 11571.69696969697
# Business : 6839.6
# Education : 6103.464285714285
# Catalogs : 5195.0
# Medical : 612.0

# %% [markdown]
# unfortunately, IOS store doesn´t have a reference for the amount of installs any app has, so we are going to use the amount of total ratings it has as reference instead to aproximate the popularity of an app

# %%
def top_downloaded_apps_by_category(ios_df, android_df, top_n=5):
    """
    Retrieves the top N most downloaded apps for each category in both iOS and Android datasets.

    Parameters:
    ios_df (pd.DataFrame): The DataFrame containing iOS app data.
    android_df (pd.DataFrame): The DataFrame containing Android app data.
    top_n (int): The number of top apps to return for each category.

    Returns:
    tuple: Two DataFrames, one for iOS and one for Android, containing the top apps by category.
    """
    
    # For iOS, since we are using rating_count_tot as a proxy for downloads
    ios_top_apps = (ios_df.sort_values(by='rating_count_tot', ascending=False)
                    .groupby('prime_genre')
                    .head(top_n)
                    .reset_index(drop=True))
    
    ios_top_apps = ios_top_apps[['prime_genre', 'track_name', 'rating_count_tot']]
    ios_top_apps = ios_top_apps.rename(columns={'prime_genre': 'Category', 'track_name': 'App Name', 'rating_count_tot': 'Total Ratings'})
    
    print("Top downloaded apps in iOS by category:")
    for category in ios_top_apps['Category'].unique():
        print(f"\nCategory: {category}")
        print(ios_top_apps[ios_top_apps['Category'] == category].to_string(index=False))
    
    # For Android, we are using Reviews to determine the apps with the most engagement, since a lot of apps often come pre-installed in Android devices.
    android_top_apps = (android_df.sort_values(by='Reviews', ascending=False)
                        .groupby('Category')
                        .head(top_n)
                        .reset_index(drop=True))
    
    android_top_apps = android_top_apps[['Category', 'App', 'Reviews']]
    android_top_apps = android_top_apps.rename(columns={'App': 'App Name', 'Reviews': 'Total Ratings'})
    
    print("\nTop downloaded apps in Android by category:")
    for category in android_top_apps['Category'].unique():
        print(f"\nCategory: {category}")
        print(android_top_apps[android_top_apps['Category'] == category].to_string(index=False))
    
    return ios_top_apps, android_top_apps

# %%
ios_top_apps, android_top_apps = top_downloaded_apps_by_category(apple_df, google_df)
# Out:
# Top downloaded apps in iOS by category:
#
# Category: Social Networking
#          Category         App Name  Total Ratings
# Social Networking         Facebook        2974676
# Social Networking        Pinterest        1061624
# Social Networking Skype for iPhone         373519
# Social Networking        Messenger         351466
# Social Networking           Tumblr         334293
#
# Category: Photo & Video
#      Category                                           App Name  Total Ratings
# Photo & Video                                          Instagram        2161558
# Photo & Video                                           Snapchat         323905
# Photo & Video    YouTube - Watch Videos, Music, and Live Streams         278166
# Photo & Video Pic Collage - Picture Editor & Photo Collage Maker         123433
# Photo & Video  Funimate video editor: add cool effects to videos         123268
#
# Category: Games
# Category         App Name  Total Ratings
#    Games   Clash of Clans        2130805
#    Games       Temple Run        1724546
#    Games Candy Crush Saga         961794
#    Games      Angry Birds         824451
#    Games   Subway Surfers         706110
#
# Category: Music
# Category                                          App Name  Total Ratings
#    Music                           Pandora - Music & Radio        1126879
#    Music                                     Spotify Music         878563
#    Music Shazam - Discover music, artists, videos & lyrics         402925
#    Music                        SoundCloud - Music & Audio         135744
#    Music                              Magic Piano by Smule         131695
#
# Category: Reference
#  Category                                           App Name  Total Ratings
# Reference                                              Bible         985920
# Reference              Dictionary.com Dictionary & Thesaurus         200047
# Reference     Dictionary.com Dictionary & Thesaurus for iPad          54175
# Reference                                   Google Translate          26786
# Reference Muslim Pro: Ramadan 2017 Prayer Times, Azan, Quran          18418
#
# Category: Health & Fitness
#         Category                                       App Name  Total Ratings
# Health & Fitness Calorie Counter & Diet Tracker by MyFitnessPal         507706
# Health & Fitness                                Weight Watchers         136833
# Health & Fitness                        Sleep Cycle alarm clock         104539
# Health & Fitness                                         Fitbit          90496
# Health & Fitness                            Period Tracker Lite          53620
#
# Category: Weather
# Category                                        App Name  Total Ratings
#  Weather   The Weather Channel: Forecast, Radar & Alerts         495626
#  Weather WeatherBug - Local Weather, Radar, Maps, Alerts         188583
#  Weather             MyRadar NOAA Weather Radar Forecast         150158
#  Weather                  AccuWeather - Weather for Life         144214
#  Weather                                   Yahoo Weather         112603
#
# Category: Travel
# Category                                       App Name  Total Ratings
#   Travel                                   Google Earth         446185
#   Travel Yelp - Nearby Restaurants, Shopping & Services         223885
#   Travel                                       GasBuddy         145549
#   Travel         TripAdvisor Hotels Flights Restaurants          56194
#   Travel                                           Uber          49466
#
# Category: Shopping
# Category                                           App Name  Total Ratings
# Shopping   Groupon - Deals, Coupons & Discount Shopping App         417779
# Shopping eBay: Best App to Buy, Sell, Save! Online Shopping         262241
# Shopping                           Wish - Shopping Made Fun         141960
# Shopping            shopkick - Shopping Rewards & Discounts         130823
# Shopping  Amazon App: shop, scan, compare, and read reviews         126312
#
# Category: News
# Category                                           App Name  Total Ratings
#     News                                            Twitter         354058
#     News                                           Fox News         132703
#     News          CNN: Breaking US & World News, Live Video         112886
#     News Reddit Official App: All That's Trending and Viral          67560
#     News                                          USA TODAY          61724
#
# Category: Navigation
#   Category                                         App Name  Total Ratings
# Navigation  Waze - GPS Navigation, Maps & Real-time Traffic         345046
# Navigation               Google Maps - Navigation & Transit         154911
# Navigation ImmobilienScout24: Real Estate Search in Germany            187
# Navigation                             Railway Route Search              5
#
# Category: Lifestyle
#  Category                                           App Name  Total Ratings
# Lifestyle     Zillow Real Estate - Homes for Sale & for Rent         342969
# Lifestyle                                             Tinder         143040
# Lifestyle            Text Free: Free Texting + Calling + MMS         100477
# Lifestyle                                        PINK Nation          49816
# Lifestyle Perfect365 - Custom makeup designs and beauty tips          19540
#
# Category: Entertainment
#      Category                                  App Name  Total Ratings
# Entertainment                                   Netflix         308844
# Entertainment         Fandango Movies - Times + Tickets         291787
# Entertainment         Colorfy: Coloring Book for Adults         247809
# Entertainment IMDb Movies & TV - Trailers and Showtimes         183425
# Entertainment                   TRUTH or DARE!!! - FREE         171055
#
# Category: Food & Drink
#     Category                            App Name  Total Ratings
# Food & Drink                           Starbucks         303856
# Food & Drink                  Domino's Pizza USA         258624
# Food & Drink OpenTable - Restaurant Reservations         113936
# Food & Drink           Allrecipes Dinner Spinner         109349
# Food & Drink            DoorDash - Food Delivery          25947
#
# Category: Sports
# Category                                           App Name  Total Ratings
#   Sports ESPN: Get scores, news, alerts & watch live sports         290996
#   Sports                               Yahoo Fantasy Sports         190670
#   Sports                                          WatchESPN         159735
#   Sports                             The Masters Tournament         148160
#   Sports    Yahoo Sports - Teams, Scores, News & Highlights         137951
#
# Category: Finance
# Category                                           App Name  Total Ratings
#  Finance      Mint: Personal Finance, Budget, Bills & Money         232940
#  Finance                   Bank of America - Mobile Banking         119773
#  Finance             PayPal - Send and request money safely         119487
#  Finance Credit Karma: Free Credit Scores, Reports & Alerts         101679
#  Finance                                 Capital One Mobile          56110
#
# Category: Education
#  Category                                  App Name  Total Ratings
# Education Duolingo - Learn Spanish, French and more         162701
# Education                 Lumosity - Brain Training          96534
# Education        Elevate - Brain Training and Games          58092
# Education                        Fit Brains Trainer          46363
# Education                                 ClassDojo          35440
#
# Category: Productivity
#     Category                                          App Name  Total Ratings
# Productivity                         Evernote - stay organized         161065
# Productivity Gmail - email by Google: secure, fast & organized         135962
# Productivity     iTranslate - Language Translator & Dictionary         123215
# Productivity                 Yahoo Mail - Keeps You Organized!         113709
# Productivity                                       Google Docs          64259
#
# Category: Utilities
#  Category                                          App Name  Total Ratings
# Utilities                                        My Verizon         126948
# Utilities                                            myAT&T         108507
# Utilities       The Calculator - Free and Easy Calculating!          99244
# Utilities                                Speedtest by Ookla          65016
# Utilities Alarm Clock HD Free - Digital Alarm Clock Display          54496
#
# Category: Book
# Category                                          App Name  Total Ratings
#     Book      Color Therapy Adult Coloring Book for Adults          84062
#     Book                             HOOKED - Chat Stories          47829
#     Book BookShout: Read eBooks & Track Your Reading Goals            879
#     Book                                 Green Riding Hood            392
#     Book                                   Weirdwood Manor            197
#
# Category: Business
# Category                                           App Name  Total Ratings
# Business                                  Indeed Job Search          38681
# Business Adobe Acrobat Reader: View, Create, & Convert PDFs          20069
# Business                    Scanner App - PDF Document Scan          11696
# Business                                    SayHi Translate           8623
# Business                               ADP Mobile Solutions           8324
#
# Category: Catalogs
# Category                                        App Name  Total Ratings
# Catalogs   CPlus for Craigslist app - mobile classifieds          13345
# Catalogs DRAGONS MODS FREE for Minecraft PC Game Edition           2027
# Catalogs      Ringtone Remixes - Marimba Remix Ringtones            213
#
# Category: Medical
# Category                                   App Name  Total Ratings
#  Medical             SnoreLab : Record Your Snoring           1341
#  Medical                               Blink Health           1198
#  Medical                           Complete Anatomy           1104
#  Medical MyDx One: Find a Strain that Works for You             29
#  Medical                Malodo : Stop au mal de dos              0
#
# Top downloaded apps in Android by category:
#
# Category: SOCIAL
# Category      App Name  Total Ratings
#   SOCIAL      Facebook       78158306
#   SOCIAL     Instagram       66577446
#   SOCIAL      Snapchat       17015352
#   SOCIAL Facebook Lite        8606259
#   SOCIAL            VK        5793284
#
# Category: COMMUNICATION
#      Category                                    App Name  Total Ratings
# COMMUNICATION                          WhatsApp Messenger       69119316
# COMMUNICATION UC Browser - Fast Download Private & Secure       17714850
# COMMUNICATION                 BBM - Free Calls & Messages       12843436
# COMMUNICATION                             Viber Messenger       11335481
# COMMUNICATION                 LINE: Free Calls & Messages       10790289
#
# Category: GAME
# Category         App Name  Total Ratings
#     GAME   Clash of Clans       44893888
#     GAME   Subway Surfers       27725352
#     GAME     Clash Royale       23136735
#     GAME Candy Crush Saga       22430188
#     GAME   My Talking Tom       14892469
#
# Category: TOOLS
# Category                                           App Name  Total Ratings
#    TOOLS            Clean Master- Space Cleaner & Antivirus       42916526
#    TOOLS Security Master - Antivirus, VPN, AppLock, Booster       24900999
#    TOOLS    360 Security - Free Antivirus, Booster, Cleaner       16771865
#    TOOLS  DU Battery Saver - Battery Charger & Battery Life       13479633
#    TOOLS Cache Cleaner-DU Speed Booster (booster & cleaner)       12759815
#
# Category: VIDEO_PLAYERS
#      Category                                           App Name  Total Ratings
# VIDEO_PLAYERS                                            YouTube       25655305
# VIDEO_PLAYERS             VivaVideo - Video Editor & Photo Movie        9879473
# VIDEO_PLAYERS                                          MX Player        6474672
# VIDEO_PLAYERS VideoShow-Video Editor, Video Maker, Beauty Camera        4016834
# VIDEO_PLAYERS                                           Dubsmash        1971777
#
# Category: NEWS_AND_MAGAZINES
#           Category                                           App Name  Total Ratings
# NEWS_AND_MAGAZINES                                            Twitter       11667403
# NEWS_AND_MAGAZINES                       Flipboard: News For Our Time        1284018
# NEWS_AND_MAGAZINES   Dailyhunt (Newshunt) - Latest News, Viral Videos         948198
# NEWS_AND_MAGAZINES                                        Google News         878065
# NEWS_AND_MAGAZINES Reddit: Social News, Trending Memes & Funny Videos         697212
#
# Category: PHOTOGRAPHY
#    Category                                           App Name  Total Ratings
# PHOTOGRAPHY                                      Google Photos       10859051
# PHOTOGRAPHY   PicsArt Photo Studio: Collage Maker & Pic Editor        7594559
# PHOTOGRAPHY PhotoGrid: Video & Pic Collage Maker, Photo Editor        7529865
# PHOTOGRAPHY                                            Retrica        6120977
# PHOTOGRAPHY                      B612 - Beauty & Filter Camera        5282578
#
# Category: FAMILY
# Category                                 App Name  Total Ratings
#   FAMILY Minion Rush: Despicable Me Official Game       10216997
#   FAMILY                                  Hay Day       10053186
#   FAMILY                         Farm Heroes Saga        7615646
#   FAMILY                        Google Play Games        7168735
#   FAMILY           Duolingo: Learn Languages Free        6297590
#
# Category: TRAVEL_AND_LOCAL
#         Category                                           App Name  Total Ratings
# TRAVEL_AND_LOCAL                          Maps - Navigate & Explore        9235373
# TRAVEL_AND_LOCAL                                       Google Earth        2339098
# TRAVEL_AND_LOCAL                                 Google Street View        2129707
# TRAVEL_AND_LOCAL                           Booking.com Travel Deals        1830388
# TRAVEL_AND_LOCAL TripAdvisor Hotels Flights Restaurants Attractions        1162838
#
# Category: PERSONALIZATION
#        Category                                         App Name  Total Ratings
# PERSONALIZATION GO Launcher - 3D parallax Themes & HD Wallpapers        7464996
# PERSONALIZATION    CM Launcher 3D - Theme, Wallpapers, Efficient        6702776
# PERSONALIZATION      APUS Launcher - Theme, Wallpaper, Hide Apps        5783441
# PERSONALIZATION                   Hola Launcher- Theme,Wallpaper        3277209
# PERSONALIZATION    Parallel Space - Multiple accounts & Two face        3062845
#
# Category: MAPS_AND_NAVIGATION
#            Category                                           App Name  Total Ratings
# MAPS_AND_NAVIGATION Waze - GPS, Maps, Traffic Alerts & Live Navigation        7232629
# MAPS_AND_NAVIGATION                                               Uber        4928420
# MAPS_AND_NAVIGATION                GPS Navigation & Offline Maps Sygic        1421884
# MAPS_AND_NAVIGATION                                Free GPS Navigation         618562
# MAPS_AND_NAVIGATION            Moovit: Bus Time & Train Time Live Info         617477
#
# Category: SHOPPING
# Category                                           App Name  Total Ratings
# SHOPPING                           Wish - Shopping Made Fun        6212081
# SHOPPING                       Flipkart Online Shopping App        6012719
# SHOPPING       AliExpress - Smarter Shopping, Better Living        5917485
# SHOPPING           Mercado Libre: Find your favorite brands        3860225
# SHOPPING eBay: Buy & Sell this Summer - Discover Deals Now!        2788923
#
# Category: ENTERTAINMENT
#      Category                                       App Name  Total Ratings
# ENTERTAINMENT                                        Netflix        5456708
# ENTERTAINMENT                                        Hotstar        4885646
# ENTERTAINMENT Twitch: Livestream Multiplayer Games & Esports        2133296
# ENTERTAINMENT                                 Talking Angela        1828284
# ENTERTAINMENT                            Talking Ben the Dog        1633682
#
# Category: PRODUCTIVITY
#     Category                      App Name  Total Ratings
# PRODUCTIVITY ES File Explorer File Manager        5383985
# PRODUCTIVITY             Microsoft Outlook        3252896
# PRODUCTIVITY          Adobe Acrobat Reader        3016305
# PRODUCTIVITY             SwiftKey Keyboard        2764964
# PRODUCTIVITY                  Google Drive        2731211
#
# Category: HEALTH_AND_FITNESS
#           Category                                           App Name  Total Ratings
# HEALTH_AND_FITNESS Period Tracker - Period Calendar Ovulation Tracker        4559407
# HEALTH_AND_FITNESS                     Calorie Counter - MyFitnessPal        1873523
# HEALTH_AND_FITNESS               Runtastic Running App & Mile Tracker         827653
# HEALTH_AND_FITNESS                                     Nike+ Run Club         708753
# HEALTH_AND_FITNESS  Period Tracker Clue: Period and Ovulation Tracker         570242
#
# Category: SPORTS
# Category                              App Name  Total Ratings
#   SPORTS                           FIFA Soccer        3909032
#   SPORTS Top Eleven 2018 - Be a Soccer Manager        3451011
#   SPORTS         PES 2018 PRO EVOLUTION SOCCER        1721943
#   SPORTS            NBA LIVE Mobile Basketball        1690802
#   SPORTS                       Real Basketball        1605267
#
# Category: LIFESTYLE
#  Category                                       App Name  Total Ratings
# LIFESTYLE                                         Tinder        2789775
# LIFESTYLE Muslim Pro - Prayer Times, Azan, Quran & Qibla        1133393
# LIFESTYLE                                Diary with lock         815893
# LIFESTYLE                   Family Locator - GPS Tracker         726074
# LIFESTYLE                                Daily Horoscope         407589
#
# Category: BOOKS_AND_REFERENCE
#            Category                                           App Name  Total Ratings
# BOOKS_AND_REFERENCE                                              Bible        2440695
# BOOKS_AND_REFERENCE                                  Google Play Books        1433233
# BOOKS_AND_REFERENCE                                         JW Library         922752
# BOOKS_AND_REFERENCE Dictionary.com: Find Definitions for English Words         899010
# BOOKS_AND_REFERENCE                                      Amazon Kindle         814151
#
# Category: WEATHER
# Category                                           App Name  Total Ratings
#  WEATHER                 Weather & Clock Widget for Android        2371543
#  WEATHER AccuWeather: Daily Forecast & Live Weather Reports        2053404
#  WEATHER  The Weather Channel: Rain Forecast & Storm Alerts        1558437
#  WEATHER   GO Weather - Widget, Theme, Wallpaper, Efficient        1422858
#  WEATHER                                      Yahoo Weather        1312037
#
# Category: FINANCE
# Category       App Name  Total Ratings
#  FINANCE   Chase Mobile        1374549
#  FINANCE Bank of Brazil        1336246
#  FINANCE      Itau bank         957973
#  FINANCE   Credit Karma         706618
#  FINANCE         PayPal         659760
#
# Category: BUSINESS
# Category                                           App Name  Total Ratings
# BUSINESS                             Facebook Pages Manager        1279800
# BUSINESS                                        Uber Driver        1254730
# BUSINESS             OfficeSuite : Free Office + PDF Editor        1002861
# BUSINESS Vault-Hide SMS,Pics & Videos,App Lock,Cloud backup         984451
# BUSINESS             File Commander - File Manager/Explorer         758590
#
# Category: EDUCATION
#  Category                                           App Name  Total Ratings
# EDUCATION Learn languages, grammar & vocabulary with Memrise        1107948
# EDUCATION                                        Math Tricks         342918
# EDUCATION                         Learn English with Wlingua         314300
# EDUCATION                  SoloLearn: Learn to Code for Free         256079
# EDUCATION                             English with Lingualeo         254519
#
# Category: FOOD_AND_DRINK
#       Category                                         App Name  Total Ratings
# FOOD_AND_DRINK                               Domino's Pizza USA        1032935
# FOOD_AND_DRINK                                          Tastely         611136
# FOOD_AND_DRINK Zomato - Restaurant Finder and Food Delivery App         511420
# FOOD_AND_DRINK                            Foursquare City Guide         483960
# FOOD_AND_DRINK                                        Starbucks         455496
#
# Category: COMICS
# Category                                                             App Name  Total Ratings
#   COMICS                                           LINE WEBTOON - Free Comics        1013944
#   COMICS                                                     Narrator's Voice         564387
#   COMICS                                       Manga Rock - Best Manga Reader         238970
#   COMICS              comico Popular Original Cartoon Updated Everyday Comico          93965
#   COMICS GANMA! - All original stories free of charge for all original comics          57106
#
# Category: PARENTING
#  Category                                           App Name  Total Ratings
# PARENTING     Pregnancy Tracker & Countdown to Baby Due Date         658087
# PARENTING                           Feed Baby - Baby Tracker          76795
# PARENTING     Baby Sleep: White noise lullabies for newborns          62386
# PARENTING Family Album Mitene: Private Photo & Video Sharing          34336
# PARENTING                                      My baby Piano          17941
#
# Category: DATING
# Category                            App Name  Total Ratings
#   DATING      Zoosk Dating App: Meet Singles         516917
#   DATING            Moco - Chat, Meet People         313769
#   DATING Hot or Not - Find someone right now         305737
#   DATING                      OkCupid Dating         285838
#   DATING        Hitwe - meet people and chat         243950
#
# Category: HOUSE_AND_HOME
#       Category                                           App Name  Total Ratings
# HOUSE_AND_HOME Zillow: Find Houses for Sale & Apartments for Rent         417907
# HOUSE_AND_HOME                        Houzz Interior Design Ideas         353813
# HOUSE_AND_HOME                       Trulia Real Estate & Rentals         175293
# HOUSE_AND_HOME   Realtor.com Real Estate: Homes for Sale and Rent         162243
# HOUSE_AND_HOME                        Alfred Home Security Camera         103305
#
# Category: LIBRARIES_AND_DEMO
#           Category                   App Name  Total Ratings
# LIBRARIES_AND_DEMO    MX Player Codec (ARMv7)         332083
# LIBRARIES_AND_DEMO                  Cardboard         130287
# LIBRARIES_AND_DEMO Aviary Stickers: Free Pack         126862
# LIBRARIES_AND_DEMO    Aviary Effects: Classic          67007
# LIBRARIES_AND_DEMO       Wifi Connect Library          58055
#
# Category: ART_AND_DESIGN
#       Category                                           App Name  Total Ratings
# ART_AND_DESIGN                         Textgram - write on photos         295237
# ART_AND_DESIGN                                       ibis Paint X         224399
# ART_AND_DESIGN                              Sketch - Draw & Paint         215644
# ART_AND_DESIGN                      FlipaClip - Cartoon animation         194216
# ART_AND_DESIGN Canva: Poster, banner, card maker & graphic design         174531
#
# Category: AUTO_AND_VEHICLES
#          Category                                                                                  App Name  Total Ratings
# AUTO_AND_VEHICLES                                             Android Auto - Maps, Media, Messaging & Voice         271920
# AUTO_AND_VEHICLES                                                                   Tickets + PDA 2018 Exam         197136
# AUTO_AND_VEHICLES                                                             AutoScout24 - used car finder         186648
# AUTO_AND_VEHICLES Fines of the State Traffic Safety Inspectorate are official: inspection, payment of fines         116986
# AUTO_AND_VEHICLES                                                                   Fuelio: Gas log & costs          65786
#
# Category: MEDICAL
# Category                                         App Name  Total Ratings
#  MEDICAL                     My Calendar - Period Tracker         156410
#  MEDICAL Ovia Pregnancy Tracker & Baby Countdown Calendar         102858
#  MEDICAL                          Ada - Your Health Guide          87418
#  MEDICAL                           Pregnancy Week By Week          78825
#  MEDICAL                      Anatomy Learning - 3D Atlas          72167
#
# Category: BEAUTY
# Category                       App Name  Total Ratings
#   BEAUTY  Beauty Camera - Selfie Camera         113715
#   BEAUTY ipsy: Makeup, Beauty, and Tips          49790
#   BEAUTY   Best Hairstyles step by step          45452
#   BEAUTY                    Ulta Beauty          42050
#   BEAUTY     Mirror - Zoom & Exposure -          32090
#
# Category: EVENTS
# Category                                        App Name  Total Ratings
#   EVENTS                      Ticketmaster Event Tickets          40113
#   EVENTS  StubHub - Tickets to Sports, Concerts & Events          26089
#   EVENTS                                           Fever          20611
#   EVENTS Gametime - Tickets to Sports, Concerts, Theater           8800
#   EVENTS                                        Reminder           7074

# %% [markdown]
# **Based on the data for IOS, we can infer some things:**
#
# Social Networking, Gaming, and Photo & Video categories dominate user engagement, making them a solid point to focus on for determining which apps are the most profitable.
# Social Networking apps have the highest total ratings, making it by far the most relevant category in app usage, likely due to continuous engagement from users on apps like Facebook or Pintrest.
# Similarly, the Photo & Video category has high user engagement, reflecting the interest in visual content sharing that has been trending for the past couple of years, with apps like Instagram, Snapchat and YouTube as the leading apps.
# The Games category also shows significant engagement with apps like Clash of Clans and Temple Run, suggesting that gaming remains a favorite among users, driving high download rates.
# In the Music category, apps like Pandora and Spotify are prominent, highlighting the ongoing popularity of music streaming services.
#
# **As for the top downloaded Android apps:**
#
# The most used Android apps tend to be apps that generally come pre-installed in the phone, like all of the Google ecosystem apps, like Google Drive, Google Calendar, Gmail, or Google Maps, which lead their respective categories with over 1 billion installs, considering that the OS itself is managed by Google.
# As such, instead of using the amount of installs, we'll also use the total reviews for each app as reference for app engagement.
# We can see that social networking, photo and video apps dominate the market in Android as well, with apps like Facebook, Instagram, WhatsApp and Youtube having huge amounts of engagement.
# In gaming, we can also see Clash of Clans being the most popular game in the store, followed by Temple Run, Candy Crush, Angry birds and Subway Surfers.
#
# **Overall:**
#
# Both stores have slightly different ways to classify their apps, but we can overall see some similarities in certain fields.
# For example, the dominance of Meta apps is consistent across both platforms, with Facebook, Instagram, and WhatsApp leading in both ecosystems.
# Both platforms see high engagement with Clash of Clans and Candy Crush Saga, showing that these games are popular across ecosystems. However, PUBG Mobile is a top contender on iOS, whereas Subway Surfers and Clash Royale have a stronger presence on Android.
# YouTube and Netflix are the top choices for streaming in both cases, but Disney+ is more prominent on iOS compared to Hotstar on Android.
# While Google Drive and Outlook appear on both platforms (strong on iOS and also top-rated on Android), Android shows a stronger focus on utility apps like antivirus and file management, which are less prevalent on iOS.
# In general, Android users seem to prefer more utility and tools-oriented apps (e.g., antivirus, file management), while iOS users gravitate toward more premium or specialized services (e.g., Calm, Disney+). Shopping habits differ as well, with Amazon being stronger on iOS and Flipkart being more prominent on Android.
# This highlights both the global dominance of certain apps and the subtle platform-specific preferences across various categories.

# %% [markdown]
# From this for both Android and iOS platforms, we can make some deductions about the most profitable apps. Also, historically, iOS users tend to spend more on apps and in-app purchases than Android users, while Android dominates in markets with large user bases, offering higher potential for ad revenue.
#
# **Social Media & Communication Apps:**
# These apps typically earn revenue through advertising (e.g., Facebook, Instagram), and some might have premium features (e.g., WhatsApp Business or Telegram subscriptions). They have massive user bases and are highly profitable due to advertising. However, apps like Facebook and Instagram are likely the most profitable because they leverage billions of users globally, which makes for a tricky market to find success in.
#
# **Streaming & Entertainment Apps:**
# Subscription models drive revenue for streaming apps like Netflix and YouTube Premium, while free versions rely on ad revenue. Streaming apps have recurring subscription revenue, making them highly profitable. However, securing the rights to legally stream IPs, and build a reliable platform might be a lot more complex than other alternatives, considering how monolithic the current streaming platforms are.
#
# **Finance and Payment, and Shopping Apps:**
# These apps face an issue similar to streaming and entertainement apps, their barrier of entry might be too high, while they could be highly profitable as well, they could be too complex to set up and market, as well as needing a massive userbase to become profitable.
#
# **Gaming Apps:**
# Games are often highly profitable due to in-app purchases, and ads. Successful mobile games like Clash of Clans generate billions through in-app purchases. These games dominate both platforms and have monetization models that include in-app purchases for upgrades, cosmetic items, or lives. It has high potential for profitability, as the userbase is massive and dynamic, but also is highly competitive, so it makes it a high-risk, high-reward category.
#
# **Productivity & Tools Apps:**
# Tools and productivity apps tend to generate revenue through freemium models, subscriptions, and one-time purchases. Productivity apps like Google Drive and Microsoft Outlook benefit from enterprise customers, making them strong earners. However, Clean Master may be profitable due to massive Android user adoption and ad revenue. This is a fairly broad category, so it could be a good
#
# **Health & Fitness and Parenting:**
# Many health apps use a subscription model or in-app purchases to access premium features like tracking, personal plans, or consultations. This is a smaller niche compared to the other categories, but it has a chance of being a lot more profitable due to that same reason. Parenting apps, especially those focused on early childhood (e.g., pregnancy trackers, baby care apps), have specific audiences with high engagement.
#
# **Lifestyle:**
# These apps are relatively easy to develop and can cater to specific needs or communities. There's also more room to introduce creative or niche ideas. For instance, apps that focus on eco-friendly habits, personal finance, or goal-setting can do well. Freemium or subscription based models could be highly effective for apps in this category.
#
# **Conclusion:**
# Health & Fitness, Education, Lifestyle, Tools & Productivity, and Parenting apps seem to offer the best balance of profitability potential and lower competition. These categories allow for niche innovation, clear monetization pathways, and relatively straightforward development without requiring massive user bases to be profitable. Freemium and subscription models tend to be highly effective in these categories, providing recurring revenue with lower barriers to entry compared to competitive sectors like gaming or social media.
